# %%
# %pip install pandas
# Out:
# ...
#      |████████████████████████████████| 10.8 MB 6.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 347 kB 13.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 5.3 MB 19.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 508 kB 48.6 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Users/pavani/Documents/Numphyninja_assignments/Team3_PyCoders_PythonHackathon_SEP2026/.venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install numpy
# Out:
# ...
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Users/pavani/Documents/Numphyninja_assignments/Team3_PyCoders_PythonHackathon_SEP2026/.venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install nbformat
# Out:
# ...
#      |████████████████████████████████| 78 kB 1.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 90 kB 6.5 MB/s eta 0:00:011
# ...
#      |████████████████████████████████| 354 kB 9.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 67 kB 16.4 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Users/pavani/Documents/Numphyninja_assignments/Team3_PyCoders_PythonHackathon_SEP2026/.venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install seaborn
# Out:
# ...
#      |████████████████████████████████| 294 kB 7.3 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Users/pavani/Documents/Numphyninja_assignments/Team3_PyCoders_PythonHackathon_SEP2026/.venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install matplotlib
# Out:
# ...
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Users/pavani/Documents/Numphyninja_assignments/Team3_PyCoders_PythonHackathon_SEP2026/.venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("/Users/pavani/Documents/Python_Hackathon_Sep_2026/cardiac_failure/demography.csv")

print(df.shape)
display(df.head())
display(df.info())
# Then:

display(df.describe(include="all").T)
# Out:
# (2009, 7)
#    inpatient_number  gender  weight  height        bmi     occupation agecat
# 0                 5     NaN     NaN     NaN  46.000000            NaN    NaN
# 1            827040  Female    50.0    1.45  23.781213            NaN  69-79
# 2            857781    Male    50.0    1.64  18.590125  UrbanResident  69-79
# 3            743087  Female    51.0    1.63  19.195303  UrbanResident  69-79
# 4            866418    Male    70.0    1.70  24.221453         farmer  59-69
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2009 entries, 0 to 2008
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   inpatient_number  2009 non-null   int64
#  1   gender            2008 non-null   object
#  2   weight            2008 non-null   float64
#  3   height            2008 non-null   float64
#  4   bmi               2009 non-null   float64
#  5   occupation        1981 non-null   object
# ...
