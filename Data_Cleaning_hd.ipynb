# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import nbformat

# %% [markdown]
# ### **1. Load and inspect the file**

# %%
hd=pd.read_csv(r"C:\Users\aruns\OneDrive\Desktop\DA211 classes recorded\python sessions\Python_Hackathon_Sep_2026-20260923T160245Z-1-001\Python_Hackathon_Sep_2026\cardiac_failure\hospitalization_discharge.csv")

# %% [markdown]
# ### **2. Check missing values as they cannot be further used to analyse data**

# %%
hd.info()
print(hd.duplicated().sum())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2008 entries, 0 to 2007
# Data columns (total 21 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   inpatient_number                                2008 non-null   int64
#  1   destinationdischarge                            2008 non-null   str
#  2   admission_ward                                  2008 non-null   str
#  3   admission_way                                   2008 non-null   str
#  4   discharge_department                            2008 non-null   str
#  5   visit_times                                     2008 non-null   int64
#  6   respiratory_support                             42 non-null     str
#  7   oxygen_inhalation                               2008 non-null   str
#  8   dischargeday                                    2008 non-null   int64
# ...

# %% [markdown]
# ### **3. Remove the completely empty columns to reduce redundancy**

# %%
empty_columns = hd.columns[hd.isna().all()]
print(empty_columns.tolist()) 

hd = hd.drop(columns=empty_columns)
# Out:
# []

# %% [markdown]
# ### **4. Changed the columns to appropriate datatypes**

# %%
hd['admission_date'] = pd.to_datetime(hd['admission_date'], errors='coerce')
hd["destinationdischarge"] = hd["destinationdischarge"].astype("string")
hd["admission_ward"] = hd["admission_ward"].astype("string")
hd["admission_way"] = hd["admission_way"].astype("string")
hd["discharge_department"] = hd["discharge_department"].astype("string")
hd["respiratory_support"] = hd["respiratory_support"].astype("string")
hd["oxygen_inhalation"] = hd["oxygen_inhalation"].astype("string")
hd["outcome_during_hospitalization"] = hd["outcome_during_hospitalization"].astype("string")

# %% [markdown]
# ### **5. Verify changes and load data**

# %%
hd.info()
hd.to_csv(r"C:\Users\aruns\OneDrive\Desktop\DA211 classes recorded\python sessions\Python_Hackathon_Sep_2026-20260923T160245Z-1-001\Python_Hackathon_Sep_2026\cardiac_failure\hospitalization_discharge_clean.csv")
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2008 entries, 0 to 2007
# Data columns (total 21 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   inpatient_number                                2008 non-null   int64
#  1   destinationdischarge                            2008 non-null   string
#  2   admission_ward                                  2008 non-null   string
#  3   admission_way                                   2008 non-null   string
#  4   discharge_department                            2008 non-null   string
#  5   visit_times                                     2008 non-null   int64
#  6   respiratory_support                             42 non-null     string
#  7   oxygen_inhalation                               2008 non-null   string
#  8   dischargeday                                    2008 non-null   int64
# ...
